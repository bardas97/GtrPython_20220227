# %% [markdown]
# ### Numpy Özet

# %% [markdown]
# * Soru:
#     1. Resimdeki diziyi oluşturalım.
#     2. Truncu alanı getiren
#     3. mavi alan
#     4. Kırmızı
#     5. Mavi Çizgili
#     6. 11, 43, 51 sayılarını getirelim
#     7. Hem 2 ye hem 3'e tam bölünen sa
#
# ![image.png](attachment:bc07f7f8-66d4-4568-9380-e3d22a326b31.png)
